# %% [markdown]
# # 02. Validación del almacenamiento
#
# Valida que el mecanismo de almacenamiento cumple sus invariantes:
#
# 1. **Capacidad**: la energía almacenada nunca supera $s_i$.
# 2. **Eficiencia**: la energía recuperada es $\eta_i \cdot f_i \cdot \tilde q_i^M$.
# 3. **Efecto intertemporal**: $\uparrow f \Rightarrow$ menos venta en M y más en E.
#
# Cubre §5.3.2.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parents[1]))

import numpy as np
import pandas as pd
from src.model import MarketModel

# %% [markdown]
# ## TODO
#
# - Comprobar que `agent.stored <= agent.stor_cap` para todos los agentes y días
# - Comprobar que `q_E_total = sum(q_E_directo + stored * eta)` para cada día
# - Forzar f={0, 0.5, 1} y ver el efecto sobre las cantidades vendidas

# %% [markdown]
# # 06. Diagnóstico del aprendizaje
#
# Histórico del proceso de diagnóstico y comparación de variantes de la regla de aprendizaje. Es un anexo al TFG: documenta **por qué** la regla actual es la elegida y qué problemas presentaban las anteriores.
#
# Para una narrativa textual completa, ver [`extras/notas-aprendizaje.md`](../extras/notas-aprendizaje.md).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parents[1]))

from src.model import MarketModel

# %% [markdown]
# ## TODO
#
# - Reproducir la tabla del CLAUDE.md:
#
# | Variante | Subóptimos | Gap medio |
# |---|---|---|
# | Contrafactual + regret/std | 5.1/30 | 2.6% |
# | Contrafactual + z-score | 5.1/30 | 2.6% |
# | **Solo elegida + z-score** (profesor) | **4.9/30** | **2.5%** |
# | Solo elegida + regret/std | 6.2/30 | 2.9% |
#
# - Mostrar la dinámica de las atracciones para cada variante
# - Ilustrar el problema de fijación de la versión original

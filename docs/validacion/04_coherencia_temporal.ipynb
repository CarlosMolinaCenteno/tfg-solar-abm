# %% [markdown]
# # 04. Coherencia temporal
#
# Valida el orden de las operaciones del día:
#
# 1. Los agentes deciden $f_i$ **antes** de conocer los precios.
# 2. Los precios se forman a partir de las decisiones agregadas.
# 3. El aprendizaje se actualiza con beneficios **del día** y solo afecta a decisiones **futuras**.
#
# Cubre §5.3.4.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parents[1]))

from src.model import MarketModel

# %% [markdown]
# ## TODO
#
# - Trazar la secuencia de llamadas en `step_day()`
# - Comprobar que las atracciones del día t+1 dependen solo de info ≤ t
# - Verificar con un modelo monkey-patcheado que `update_learning` se llama después de `step_day` y nunca antes

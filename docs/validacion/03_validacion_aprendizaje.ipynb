# %% [markdown]
# # 03. Validación del aprendizaje
#
# Valida que el aprendizaje:
#
# 1. **No fija** al agente en su primera elección aleatoria (problema histórico).
# 2. **Converge** asintóticamente hacia la región del óptimo teórico.
# 3. La **varianza** entre agentes disminuye con el tiempo, sin colapsar a 0.
#
# Cubre §5.3.3.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parents[1]))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from src.model import MarketModel

# %% [markdown]
# ## TODO
#
# - Trazar evolución de la fracción media para 10 semillas
# - Comprobar que la varianza temporal disminuye pero >0
# - Comparar la fracción media estabilizada con el referente teórico de §4.6 y `banco_pruebas.ipynb`
# - Reproducir la tabla de subóptimos del CLAUDE.md (10 seeds × N agentes)
